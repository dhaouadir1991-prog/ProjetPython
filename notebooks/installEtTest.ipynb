# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Legion\transformers_env\Scripts\python.exe

# %%
# %pip install fastapi uvicorn
# Out:
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 390.1 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.5/2.0 MB 390.1 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.5/2.0 MB 390.1 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.0 MB 409.0 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.0 MB 409.0 kB/s eta 0:00:04
# ...

# %%
import fastapi
import uvicorn
print("OK")
# Out:
# OK
